# %% [markdown]
# <a href="https://colab.research.google.com/github/heidaralavi/APC-PRJ/blob/main/APC-PRJ1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # گندله سازی اردکان
# بررسی ارتباط پارامترهای ورودی به میکسرهای
# و گندله خروجی

# %% [markdown]
# ابتدا توابع مورد نیاز را ایمپورت می کنیم

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import IsolationForest,RandomForestRegressor,GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error
from sklearn.preprocessing import scale , normalize, minmax_scale
from sklearn.neural_network import MLPRegressor
from sklearn.tree import DecisionTreeRegressor,plot_tree
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
import xgboost as xgb

# %% [markdown]
# داده های ورودی را که شامل پارامترهای کنسانتره ورودی به میکسر است را وارد می کنیم

# %%
url = 'https://raw.githubusercontent.com/heidaralavi/APC-PRJ/main/input-data.csv'
i_df=pd.read_csv(url)
#i_df=pd.read_csv('input-data.csv')

# %%
i_df
# Out:
#           Blaine    Co-Tfe%    Co-FeO%  ...     Co-P%  Co-MnO%  Co-TiO2%
# 0    1823.333333  67.460000  22.820000  ...  0.091000   0.0310  0.222000
# 1    1837.333333  67.536667  22.656667  ...  0.100900   0.0285  0.223267
# 2    1712.333333  67.650000  22.663333  ...  0.088167   0.0272  0.270367
# 3    1794.333333  67.653333  22.506667  ...  0.094567   0.0293  0.245033
# 4    1807.666667  67.490000  23.446667  ...  0.094333   0.0310  0.213000
# ..           ...        ...        ...  ...       ...      ...       ...
# 165  1737.333333  67.553333  23.476667  ...  0.108000   0.0250  0.239333
# 166  1715.000000  67.486667  23.556667  ...  0.104667   0.0270  0.214667
# 167  1707.000000  67.666667  22.693333  ...  0.102000   0.0270  0.243000
# 168  1730.000000  67.930000  22.986667  ...  0.096500   0.0255  0.242500
# 169  1763.000000  67.735000  22.610000  ...  0.104000   0.0250  0.234000
#
# [170 rows x 10 columns]

# %% [markdown]
# داده های گندله خروجی را وارد می کنیم

# %%
url = 'https://raw.githubusercontent.com/heidaralavi/APC-PRJ/main/output-data.csv'
o_df=pd.read_csv(url)
#o_df=pd.read_csv('output-data.csv')

# %%
o_df
# Out:
#      PL-CCS kg/pl  PL-Tfe%  PL-FeO%  ...  PL-TiO2%  PL-CaO%  PL-MgO%
# 0             287    65.46     0.47  ...      0.21     0.64     0.42
# 1             258    65.49     0.53  ...      0.22     0.66     0.43
# 2             298    65.62     0.63  ...      0.27     0.62     0.41
# 3             312    65.66     0.99  ...      0.22     0.63     0.42
# 4             314    65.56     0.89  ...      0.21     0.66     0.42
# ..            ...      ...      ...  ...       ...      ...      ...
# 165           311    65.73     0.64  ...      0.26     0.67     0.45
# 166           305    65.79     0.59  ...      0.28     0.66     0.44
# 167           305    65.90     0.73  ...      0.23     0.61     0.38
# 168           294    65.92     0.58  ...      0.20     0.60     0.39
# 169           303    66.12     1.16  ...      0.18     0.60     0.41
#
# [170 rows x 17 columns]

# %% [markdown]
# یکی از ستون های گندله را به انتهای پارامترهای کنسانتره اضافه می کنیم و دیتافریم جدید می سازیم

# %%
df=pd.concat([i_df, o_df.iloc[:,8]], axis=1)

# %%
df
# Out:
#           Blaine    Co-Tfe%    Co-FeO%  ...  Co-MnO%  Co-TiO2%  Abrasion%
# 0    1823.333333  67.460000  22.820000  ...   0.0310  0.222000       1.75
# 1    1837.333333  67.536667  22.656667  ...   0.0285  0.223267       2.39
# 2    1712.333333  67.650000  22.663333  ...   0.0272  0.270367       2.01
# 3    1794.333333  67.653333  22.506667  ...   0.0293  0.245033       1.69
# 4    1807.666667  67.490000  23.446667  ...   0.0310  0.213000       2.00
# ..           ...        ...        ...  ...      ...       ...        ...
# 165  1737.333333  67.553333  23.476667  ...   0.0250  0.239333       2.37
# 166  1715.000000  67.486667  23.556667  ...   0.0270  0.214667       2.29
# 167  1707.000000  67.666667  22.693333  ...   0.0270  0.243000       2.21
# 168  1730.000000  67.930000  22.986667  ...   0.0255  0.242500       1.74
# 169  1763.000000  67.735000  22.610000  ...   0.0250  0.234000       2.07
#
# [170 rows x 11 columns]

# %% [markdown]
# # بررسی اولیه داده ها

# %% [markdown]
# دیتاها را نسبت به هم ترسیم می کنیم تا دیدی کلی از داده ها بدست آوریم

# %%
plt.figure(dpi=200)
pd.plotting.scatter_matrix(df, c='blue',alpha=0.35, s=55,figsize=[26,26])
plt.show()

# %% [markdown]
# ماتریس ضریب همبستگی دیتاها را محاسبه و ترسیم می کنیم

# %%
corr = df.corr()
print(corr.shape)
plt.figure(figsize=(11,11))
sns.heatmap(corr, cbar=False,square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# (11, 11)

# %% [markdown]
# بررسی داده های از دست رفته و ناقص

# %%
import missingno as msno
msno.matrix(df) # just to visualize. no missing values.

# %%
# It seems there are no Null Values.
# Let's Confirm
df.isnull().sum()
# Out:
# Blaine       0
# Co-Tfe%      0
# Co-FeO%      0
# Co-SiO2%     0
# Co-CaO%      0
# Co-MgO%      0
# Co-AL2O3%    0
# Co-P%        0
# Co-MnO%      0
# Co-TiO2%     0
# Abrasion%    0
# dtype: int64

# %%
df.describe()
# Out:
#             Blaine     Co-Tfe%     Co-FeO%  ...     Co-MnO%    Co-TiO2%   Abrasion%
# count   170.000000  170.000000  170.000000  ...  170.000000  170.000000  170.000000
# mean   1802.720588   67.717333   23.313784  ...    0.025549    0.246898    1.987824
# std      87.995770    0.232891    0.701742  ...    0.003099    0.039237    0.243450
# min    1554.500000   67.175000   21.430000  ...    0.013000    0.198000    1.530000
# 25%    1741.000000   67.537500   22.860000  ...    0.024375    0.220333    1.830000
# 50%    1814.000000   67.695000   23.356667  ...    0.025933    0.237000    1.965000
# 75%    1871.666667   67.852500   23.836250  ...    0.027625    0.259500    2.130000
# max    1978.000000   68.330000   24.790000  ...    0.031000    0.390000    3.520000
#
# [8 rows x 11 columns]

# %%
sns.catplot(data=df, kind='box' , height=7, aspect=2.5)

# %%
sns.catplot(data=df.iloc[:,3:4], kind='box' , height=7, aspect=2.5)

# %%
sns.kdeplot(df.iloc[:,0], shade=True , color='r')

# %%
sns.kdeplot(data=df.iloc[:,4:7],shade=True)

# %%
sns.jointplot(x=df.iloc[:,0] , y=df.iloc[:,5], data=df , height=5)

# %%
sns.catplot(x='Blaine', data=df , kind='count',aspect=2.5 )

# %%
#sns.catplot(x=df.iloc[:,1], y=df.iloc[:,4] , data=df , kind='violin', aspect=2.5)

# %%
sns.catplot(data=df.iloc[:,3:5], kind='violin' , height=7, aspect=2.5)

# %% [markdown]
# # پالایش داده ها

# %% [markdown]
# داده های پرت و نویز را شناسایی و از دیتافریم حذف می کنیم

# %%
col=df.columns
data=df.values
print(data.shape)
print(col)
# Out:
# (170, 11)
# Index(['Blaine', 'Co-Tfe%', 'Co-FeO%', 'Co-SiO2%', 'Co-CaO%', 'Co-MgO%',
#        'Co-AL2O3%', 'Co-P%', 'Co-MnO%', 'Co-TiO2%', 'Abrasion%'],
#       dtype='object')

# %%
# identify outliers in the dataset
iso = IsolationForest()
yhat = iso.fit_predict(data)

# %%
print(yhat.shape)
# Out:
# (170,)

# %%
# select all rows that are not outliers
mask = yhat != -1

# %%
mask
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True,  True,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False,  True,
#         True, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True, False,  True,  True,  True,
#        False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False])

# %%
data = data[mask, :]

# %%
data.shape
# Out:
# (153, 11)

# %%
not_outliers_df=pd.DataFrame(data,columns=col)

# %%
not_outliers_df
# Out:
#           Blaine    Co-Tfe%    Co-FeO%  ...   Co-MnO%  Co-TiO2%  Abrasion%
# 0    1823.333333  67.460000  22.820000  ...  0.031000  0.222000       1.75
# 1    1837.333333  67.536667  22.656667  ...  0.028500  0.223267       2.39
# 2    1712.333333  67.650000  22.663333  ...  0.027200  0.270367       2.01
# 3    1794.333333  67.653333  22.506667  ...  0.029300  0.245033       1.69
# 4    1807.666667  67.490000  23.446667  ...  0.031000  0.213000       2.00
# ..           ...        ...        ...  ...       ...       ...        ...
# 148  1700.000000  67.603333  23.263333  ...  0.026667  0.242667       2.16
# 149  1737.333333  67.553333  23.476667  ...  0.025000  0.239333       2.37
# 150  1715.000000  67.486667  23.556667  ...  0.027000  0.214667       2.29
# 151  1707.000000  67.666667  22.693333  ...  0.027000  0.243000       2.21
# 152  1730.000000  67.930000  22.986667  ...  0.025500  0.242500       1.74
#
# [153 rows x 11 columns]

# %%
plt.figure(dpi=200)
pd.plotting.scatter_matrix(not_outliers_df, c='blue',alpha=0.35, s=55,figsize=[26,26])
plt.show()

# %%
corr = not_outliers_df.corr()
print(corr.shape)
plt.figure(figsize=(11,11))
sns.heatmap(corr, cbar=False,square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# (11, 11)

# %% [markdown]
# # نرمالسازی داده ها

# %%
data=normalize(data,norm='l2',axis=0)

# %%
normal_df=pd.DataFrame(data,columns=col)

# %%
normal_df
# Out:
#        Blaine   Co-Tfe%   Co-FeO%  ...   Co-MnO%  Co-TiO2%  Abrasion%
# 0    0.081624  0.080535  0.079161  ...  0.096454  0.072211   0.071630
# 1    0.082250  0.080627  0.078594  ...  0.088676  0.072623   0.097826
# 2    0.076655  0.080762  0.078617  ...  0.084631  0.087943   0.082272
# 3    0.080325  0.080766  0.078074  ...  0.091165  0.079703   0.069174
# 4    0.080922  0.080571  0.081335  ...  0.096454  0.069283   0.081863
# ..        ...       ...       ...  ...       ...       ...        ...
# 148  0.076102  0.080706  0.080699  ...  0.082972  0.078933   0.088412
# 149  0.077774  0.080647  0.081439  ...  0.077786  0.077849   0.097007
# 150  0.076774  0.080567  0.081716  ...  0.084009  0.069826   0.093733
# 151  0.076416  0.080782  0.078721  ...  0.084009  0.079042   0.090458
# 152  0.077445  0.081096  0.079739  ...  0.079342  0.078879   0.071221
#
# [153 rows x 11 columns]

# %%
plt.figure(dpi=200)
pd.plotting.scatter_matrix(normal_df, c='blue',alpha=0.35, s=55,figsize=[26,26])
plt.show()

# %%
corr = normal_df.corr()
print(corr.shape)
plt.figure(figsize=(11,11))
sns.heatmap(corr, cbar=False,square= True, fmt='.1f', annot=True, annot_kws={'size':10}, cmap='Greens')
# Out:
# (11, 11)

# %% [markdown]
# # جداسازی داده های آموزشی و تست

# %%
# split into input and output elements
X, y = data[:, :-1], data[:, -1]

# %%
X
# Out:
# array([[0.08162358, 0.08053526, 0.07916087, ..., 0.07295171, 0.09645449,
#         0.07221088],
#        [0.08225031, 0.08062678, 0.07859428, ..., 0.08088822, 0.0886759 ,
#         0.0726229 ],
#        [0.07665454, 0.08076208, 0.07861741, ..., 0.07068032, 0.08463104,
#         0.08794332],
#        ...,
#        [0.07677392, 0.08056709, 0.08171631, ..., 0.08390783, 0.08400875,
#         0.06982554],
#        [0.07641579, 0.08078198, 0.07872148, ..., 0.08177005, 0.08400875,
#         0.07904164],
#        [0.07744541, 0.08109635, 0.07973903, ..., 0.07736088, 0.0793416 ,
#         0.07887901]])

# %%
y
# Out:
# array([0.07162998, 0.09782609, 0.08227215, 0.06917409, 0.08186283,
#        0.07858832, 0.08841186, 0.06671821, 0.08841186, 0.06999272,
#        0.08350009, 0.06426232, 0.06999272, 0.07776969, 0.07776969,
#        0.07940695, 0.09004912, 0.09700746, 0.06712752, 0.07490449,
#        0.09209569, 0.07817901, 0.08022558, 0.07736038, 0.07613244,
#        0.07613244, 0.0839094 , 0.09864471, 0.07776969, 0.08923049,
#        0.0953702 , 0.10273786, 0.08104421, 0.0839094 , 0.08145352,
#        0.07367655, 0.08431872, 0.07654175, 0.08513735, 0.07531381,
#        0.09782609, 0.07203929, 0.07408586, 0.07162998, 0.07285792,
#        0.07326724, 0.07817901, 0.07695106, 0.07490449, 0.08227215,
#        0.07162998, 0.07531381, 0.06262507, 0.06835547, 0.07449518,
#        0.06508095, 0.07736038, 0.06467164, 0.07695106, 0.07408586,
#        0.07162998, 0.06999272, 0.06876478, 0.07449518, 0.06589958,
#        0.06589958, 0.07449518, 0.07736038, 0.07736038, 0.07408586,
#        0.06876478, 0.07776969, 0.08513735, 0.07736038, 0.07531381,
#        0.08104421, 0.07940695, 0.08431872, 0.06917409, 0.07531381,
#        0.08022558, 0.08554666, 0.09414226, 0.07858832, 0.07858832,
#        0.08431872, 0.09127706, 0.07367655, 0.08063489, 0.07899763,
#        0.08268146, 0.08268146, 0.08718392, 0.07613244, 0.08431872,
#        0.06917409, 0.08759323, 0.08841186, 0.08718392, 0.08063489,
#        0.08882117, 0.0953702 , 0.07613244, 0.08554666, 0.0867746 ,
#        0.08431872, 0.09700746, 0.09168637, 0.06999272, 0.07981626,
#        0.06671821, 0.08350009, 0.07244861, 0.07613244, 0.08063489,
#        0.07531381, 0.08145352, 0.08800255, 0.0867746 , 0.08350009,
#        0.09332363, 0.092505  , 0.07654175, 0.08923049, 0.07858832,
#        0.09127706, 0.08513735, 0.08882117, 0.08309078, 0.06835547,
#        0.08636529, 0.09496089, 0.07776969, 0.07408586, 0.09086775,
#        0.08227215, 0.07736038, 0.08759323, 0.08350009, 0.08104421,
#        0.08513735, 0.07490449, 0.07776969, 0.07449518, 0.07899763,
#        0.07572312, 0.08759323, 0.09741677, 0.08841186, 0.09700746,
#        0.09373294, 0.09045843, 0.07122067])

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
print(X_test.shape,X_train.shape)
# Out:
# (46, 10) (107, 10)

# %% [markdown]
# # استفاده از مدل رگرسیون خطی برای حل مسئله و حدس زدن جواب نمونه های آزمایشی

# %%
# fit the model
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# مدل چقدر خوب آموزش دیده است؟

# %%
ybar = model.predict(X_train)

# %%
# evaluate predictions
mae = mean_absolute_error(y_train, ybar)
print('MAE: %.3f' %mae)
# Out:
# MAE: 0.006

# %%
plt.scatter(y_train, ybar)
plt.xlabel('Real Value')
plt.ylabel('predictet Value')
plt.show()

# %%
print("The Train Score is ", (r2_score( y_train, ybar)))
# Out:
# The Train Score is  0.15773173493814419

# %% [markdown]
# مدل چقدر خوب حدس می زند؟

# %%
# evaluate the model
yhat = model.predict(X_test)

# %%
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' %mae)
# Out:
# MAE: 0.006

# %%
plt.scatter(y_test,yhat)
plt.xlabel('Real Value')
plt.ylabel('predictet Value')
plt.show()

# %%
print("The Predict Score is ", (r2_score( y_test,yhat)))
# Out:
# The Predict Score is  0.05470231154398297

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %% [markdown]
# # استفاده از شبکه عصبی برای حل مسئله و حدس زدن جواب نمونه های آزمایشی

# %%
model = MLPRegressor(hidden_layer_sizes=(100,),activation="relu" ,random_state=1, max_iter=200000)
model.fit(X_train, y_train)
# Out:
# MLPRegressor(max_iter=200000, random_state=1)

# %% [markdown]
# مدل چقدر خوب آموزش دیده است؟

# %%
ybar = model.predict(X_train)

# %%
# evaluate predictions
mae = mean_absolute_error(y_train, ybar)
print('MAE: %.3f' %mae)
# Out:
# MAE: 0.034

# %%
plt.scatter(y_train, ybar)
plt.xlabel('Real Value')
plt.ylabel('predictet Value')
plt.show()

# %%
print("The Train Score is ", (r2_score( y_train, ybar)))
# Out:
# The Train Score is  -15.771030515042895

# %% [markdown]
# مدل چقدر خوب حدس می زند؟

# %%
# evaluate the model
yhat = model.predict(X_test)

# %%
print("The Train Score is: ", (r2_score( y_test,yhat)))
# Out:
# The Train Score is:  -18.57536995077344

# %%
plt.scatter(y_test,yhat)
plt.xlabel('Real Value')
plt.ylabel('predictet Value')
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %% [markdown]
# # Decision Tree Regression

# %%
model = DecisionTreeRegressor(random_state=123)
model = model.fit(X_train,y_train)

# %%
print("Accuracy on test: {:.2f} %".format(model.score(X_test, y_test)*100))
# Out:
# Accuracy on test: -141.50 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: -141.50%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
model.feature_importances_
# Out:
# array([0.06711519, 0.02963798, 0.27115649, 0.0333697 , 0.08013095,
#        0.24495739, 0.01376754, 0.0410451 , 0.09392712, 0.12489255])

# %%
plt.figure(figsize=(8,6))
n_features = len(col)-1
plt.barh(range(n_features), model.feature_importances_, align='center')
plt.yticks(np.arange(len(col)-1), col[:-1])
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.ylim(-1, n_features)
# Out:
# (-1.0, 10.0)

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %% [markdown]
# # Support Vector Regression

# %%
model=SVR()
model.fit(X_train,y_train)
# Out:
# SVR()

# %%
print("Accuracy score {:.2f} %\n".format(model.score(X_test,y_test)*100))
# Out:
# Accuracy score -1.00 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: -1.00%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %% [markdown]
# # K-Nearest Neighbor Regressor

# %%
model=KNeighborsRegressor(n_jobs=-1)
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_jobs=-1)

# %%
print("Accuracy score {:.2f} %\n".format(model.score(X_test,y_test)*100))
# Out:
# Accuracy score -7.99 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: -7.99%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %% [markdown]
# # Random Forest Regressor

# %%
model = RandomForestRegressor(n_jobs = -1,random_state = 123)
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=123)

# %%
print("Accuracy score {:.2f} %\n".format(model.score(X_test,y_test)*100))
# Out:
# Accuracy score 0.91 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: 0.91%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %%
plt.figure(figsize=(8,6))
n_features = len(col)-1
plt.barh(range(n_features), model.feature_importances_, align='center')
plt.yticks(np.arange(len(col)-1), col[:-1])
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.ylim(-1, n_features)
# Out:
# (-1.0, 10.0)

# %% [markdown]
# # Gradient Boosting Regressor

# %%
model = GradientBoostingRegressor(random_state = 123)
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=123)

# %%
print("Accuracy score {:.2f} %\n".format(model.score(X_test,y_test)*100))
# Out:
# Accuracy score -16.17 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: -16.17%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()

# %%
plt.figure(figsize=(8,6))
n_features = len(col)-1
plt.barh(range(n_features), model.feature_importances_, align='center')
plt.yticks(np.arange(len(col)-1), col[:-1])
plt.xlabel("Feature importance")
plt.ylabel("Feature")
plt.ylim(-1, n_features)
# Out:
# (-1.0, 10.0)

# %% [markdown]
# # Extreme Gradient Boosting Regressor

# %%
model = XGBRegressor(random_state = 123,n_jobs=-1)
model.fit(X_train, y_train)
# Out:
# [05:47:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(n_jobs=-1, random_state=123)

# %%
print("Accuracy score {:.2f} %\n".format(model.score(X_test,y_test)*100))
# Out:
# Accuracy score 12.09 %

# %%
y_pred = model.predict(X_test)
print("R2 Score: {:.2f}%".format(r2_score(y_test,y_pred)*100))
print("Mean Absolute Error {:.2f}".format(mean_absolute_error(y_test,y_pred)))
print("Mean Squared Error {:.2f}".format(mean_squared_error(y_test,y_pred)))
# Out:
# R2 Score: 12.09%
# Mean Absolute Error 0.01
# Mean Squared Error 0.00

# %%
xgb.plot_importance(model,importance_type="gain",show_values=False)
plt.rcParams['figure.figsize'] = [5, 5]
plt.show()

# %%
plt.figure(figsize=(14,10))
plt.plot(range(20),y_test[0:20], color = "green")
plt.plot(range(20),model.predict(X_test[0:20]), color = "red")
plt.legend(["Actual","prediction"]) 
plt.title("Predicted vs True Value")
plt.xlabel("Record number")
plt.ylabel(col[-1])
plt.show()
